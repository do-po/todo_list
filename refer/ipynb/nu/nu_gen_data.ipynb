# %% [markdown]
# ## 알고리즘 시험용으로 DB에 저장할 랜덤한 데이터들을 생성하는 코드

# %% [markdown]
# ### 필요한 라이브러리 로드

# %%
# 라이브러리 로드

from refer.module.func import save_data
import pandas as pd
from refer.module.database import MyDB

db = MyDB()

# %% [markdown]
# ### user_info
#
# - user_id
# - password
# - birth
# - gender
# - job
# - mbti

# %%
import pandas as pd
import random
import string
from datetime import datetime

# 랜덤한 user_id 생성 함수
def generate_user_id(length=10):
    return ''.join(random.choices(string.ascii_letters + string.digits, k=length))

# 랜덤한 password 생성 함수
def generate_password(length=12):
    return ''.join(random.choices(string.ascii_letters + string.digits + string.punctuation, k=length))

# 랜덤한 birth 날짜 생성 함수
def generate_birth(start_year=1950, end_year=2005):
    start_date = datetime(start_year, 1, 1)
    end_date = datetime(end_year, 12, 31)
    return start_date + (end_date - start_date) * random.random()

# 랜덤한 나이, 성별, 직업, mbti 생성 함수
def generate_random_data(num_records=100):
    data = {
        'user_id': [],
        'password': [],
        'birth': [],
        'gender': [],
        'job': [],
        'mbti': []
    }
    
    for _ in range(num_records):
        data['user_id'].append(generate_user_id())
        data['password'].append(generate_password())
        data['birth'].append(generate_birth().strftime('%Y-%m-%d'))
        data['gender'].append(random.randint(0, 1))
        data['job'].append(random.randint(1, 9))
        data['mbti'].append(random.randint(1, 16))
    
    return pd.DataFrame(data)

# 데이터 생성
num_records = 100  # 생성할 레코드 수
user_info_data = generate_random_data(num_records)

# 데이터를 데이터베이스에 저장
save_data(user_info_data, 'user_info')
# Out:
# sql query :
#     INSERT INTO `user_info`
#     (user_id,password,birth,gender,job,mbti)
#     VALUES
#     (%s,%s,%s,%s,%s,%s)
#
# sql insert data :  {'user_id': 'A0a5IkJMrm', 'password': 'A+J>6V_~7$a$', 'birth': '2003-06-12', 'gender': 1, 'job': 4, 'mbti': 14}
# sql query :
#     INSERT INTO `user_info`
#     (user_id,password,birth,gender,job,mbti)
#     VALUES
#     (%s,%s,%s,%s,%s,%s)
#
# sql insert data :  {'user_id': '5vtBcEJZB7', 'password': 'Rg.rwF@}.8D+', 'birth': '1986-11-23', 'gender': 0, 'job': 2, 'mbti': 6}
# sql query :
#     INSERT INTO `user_info`
#     (user_id,password,birth,gender,job,mbti)
#     VALUES
#     (%s,%s,%s,%s,%s,%s)
#
# sql insert data :  {'user_id': 'vX1RDnmedL', 'password': "'Bi`WMZ\\}6.C", 'birth': '2005-01-02', 'gender': 0, 'job': 6, 'mbti': 8}
# sql query :
#     INSERT INTO `user_info`
#     (user_id,password,birth,gender,job,mbti)
#     VALUES
#     (%s,%s,%s,%s,%s,%s)
#
# sql insert data :  {'user_id': 'xnGUPugAtK', 'password': 'J%6K}>GKwHMq', 'birth': '1996-09-09', 'gender': 0, 'job': 6, 'mbti': 3}
# sql query :
#     INSERT INTO `user_info`
#     (user_id,password,birth,gender,job,mbti)
#     VALUES
#     (%s,%s,%s,%s,%s,%s)
#
# sql insert data :  {'user_id': 'sWc2x7Hucj', 'password': 'yUzZ/80+>mpM', 'birth': '1981-08-15', 'gender': 1, 'job': 8, 'mbti': 13}
# sql query :
#     INSERT INTO `user_info`
#     (user_id,password,birth,gender,job,mbti)
#     VALUES
#     (%s,%s,%s,%s,%s,%s)
#
# sql insert data :  {'user_id': '2EXSzl3J2n', 'password': 'b!V^B@3LQ&Eg', 'birth': '1990-09-16', 'gender': 0, 'job': 7, 'mbti': 16}
# sql query :
#     INSERT INTO `user_info`
#     (user_id,password,birth,gender,job,mbti)
#     VALUES
#     (%s,%s,%s,%s,%s,%s)
#
# sql insert data :  {'user_id': 'LtMa0Z0R09', 'password': '#4j%y!O(9Ov,', 'birth': '1954-07-15', 'gender': 0, 'job': 8, 'mbti': 11}
# sql query :
#     INSERT INTO `user_info`
#     (user_id,password,birth,gender,job,mbti)
#     VALUES
#     (%s,%s,%s,%s,%s,%s)
#
# sql insert data :  {'user_id': 'H0HvUePjPD', 'password': '{;@kao,X0obA', 'birth': '1982-09-11', 'gender': 1, 'job': 5, 'mbti': 4}
# sql query :
#     INSERT INTO `user_info`
#     (user_id,password,birth,gender,job,mbti)
#     VALUES
#     (%s,%s,%s,%s,%s,%s)
#
# sql insert data :  {'user_id': 'Ko6VsiGJZT', 'password': 'r~VHMXd<4,<`', 'birth': '1974-07-05', 'gender': 0, 'job': 5, 'mbti': 6}
# sql query :
#     INSERT INTO `user_info`
#     (user_id,password,birth,gender,job,mbti)
#     VALUES
#     (%s,%s,%s,%s,%s,%s)
#
# sql insert data :  {'user_id': 'NI9Z4NleiX', 'password': '>x!ZH!Y)3IP[', 'birth': '1979-08-21', 'gender': 1, 'job': 7, 'mbti': 16}
# sql query :
#     INSERT INTO `user_info`
#     (user_id,password,birth,gender,job,mbti)
#     VALUES
#     (%s,%s,%s,%s,%s,%s)
#
# sql insert data :  {'user_id': 'Spo08mb51d', 'password': 'R,0GF)`DG<m:', 'birth': '1986-02-10', 'gender': 0, 'job': 6, 'mbti': 11}
# sql query :
#     INSERT INTO `user_info`
#     (user_id,password,birth,gender,job,mbti)
#     VALUES
#     (%s,%s,%s,%s,%s,%s)
#
# sql insert data :  {'user_id': 'WrtjrNcgtH', 'password': '\\zqfDkohJ4Jk', 'birth': '1990-07-05', 'gender': 1, 'job': 3, 'mbti': 7}
# sql query :
#     INSERT INTO `user_info`
#     (user_id,password,birth,gender,job,mbti)
#     VALUES
#     (%s,%s,%s,%s,%s,%s)
#
# sql insert data :  {'user_id': 'LV1U2eC0NE', 'password': 'nB=<U]z:\\@sq', 'birth': '1977-04-12', 'gender': 0, 'job': 1, 'mbti': 3}
# sql query :
#     INSERT INTO `user_info`
#     (user_id,password,birth,gender,job,mbti)
#     VALUES
#     (%s,%s,%s,%s,%s,%s)
#
# sql insert data :  {'user_id': '9CFGTbD6IL', 'password': ';t7?{Z7TVB5@', 'birth': '1977-08-20', 'gender': 1, 'job': 8, 'mbti': 9}
# sql query :
#     INSERT INTO `user_info`
#     (user_id,password,birth,gender,job,mbti)
#     VALUES
#     (%s,%s,%s,%s,%s,%s)
#
# sql insert data :  {'user_id':

# sql query :
#     INSERT INTO `user_info`
#     (user_id,password,birth,gender,job,mbti)
#     VALUES
#     (%s,%s,%s,%s,%s,%s)
#
# sql insert data :  {'user_id': 'dNQNDvFO5l', 'password': 'i.lea,,|3_TA', 'birth': '2005-09-30', 'gender': 0, 'job': 2, 'mbti': 9}
# sql query :
#     INSERT INTO `user_info`
#     (user_id,password,birth,gender,job,mbti)
#     VALUES
#     (%s,%s,%s,%s,%s,%s)
#
# sql insert data :  {'user_id': 'xiGg7gJvUl', 'password': 'Hv8Cg-zBT#&a', 'birth': '1990-04-08', 'gender': 1, 'job': 2, 'mbti': 3}
# sql query :
#     INSERT INTO `user_info`
#     (user_id,password,birth,gender,job,mbti)
#     VALUES
#     (%s,%s,%s,%s,%s,%s)
#
# sql insert data :  {'user_id': '0YttYPfeRQ', 'password': 'yq`VJebuiI|}', 'birth': '2005-04-30', 'gender': 1, 'job': 9, 'mbti': 14}
# sql query :
#     INSERT INTO `user_info`
#     (user_id,password,birth,gender,job,mbti)
#     VALUES
#     (%s,%s,%s,%s,%s,%s)
#
# sql insert data :  {'user_id': 'PNm0Slk3lc', 'password': '6U(An@u`+P?e', 'birth': '1992-04-03', 'gender': 1, 'job': 7, 'mbti': 3}
# sql query :
#     INSERT INTO `user_info`
#     (user_id,password,birth,gender,job,mbti)
#     VALUES
#     (%s,%s,%s,%s,%s,%s)
#
# sql insert data :  {'user_id': 'FlYwWQtR6m', 'password': '<h7(eKy78awQ', 'birth': '1977-07-22', 'gender': 0, 'job': 8, 'mbti': 8}
# sql query :
#     INSERT INTO `user_info`
#     (user_id,password,birth,gender,job,mbti)
#     VALUES
#     (%s,%s,%s,%s,%s,%s)
#
# sql insert data :  {'user_id': 'RV3ix4DmCH', 'password': 'nr}>TuG<<0V0', 'birth': '1967-07-16', 'gender': 1, 'job': 4, 'mbti': 1}
# sql query :
#     INSERT INTO `user_info`
#     (user_id,password,birth,gender,job,mbti)
#     VALUES
#     (%s,%s,%s,%s,%s,%s)
#
# sql insert data :  {'user_id': 'DeCpYXYkM0', 'password': "<iQoG_]&J'#c", 'birth': '2002-10-03', 'gender': 0, 'job': 9, 'mbti': 16}
# sql query :
#     INSERT INTO `user_info`
#     (user_id,password,birth,gender,job,mbti)
#     VALUES
#     (%s,%s,%s,%s,%s,%s)
#
# sql insert data :  {'user_id': 'XXY2fc1aRj', 'password': 'f;Ua%nOf;#(%', 'birth': '1973-12-07', 'gender': 0, 'job': 1, 'mbti': 16}

# %% [markdown]
# ### schedule_1
#
# - user_goal
# - goal_complexity
# - goal_start_time
# - goal_end_time

# %%
import pandas as pd
import random
import string
from datetime import datetime, timedelta
from refer.module.database import MyDB

# MyDB 클래스 생성
db = MyDB()

# 랜덤한 user_goal 생성 함수
def generate_user_goal(length=10):
    return ''.join(random.choices(string.ascii_letters + string.digits, k=length))

# 랜덤한 goal_complexity 생성 함수
def generate_goal_complexity():
    return random.randint(1, 5)

# 랜덤한 goal_start_time, goal_end_time 생성 함수
def generate_goal_times():
    start_time = datetime.now() + timedelta(days=random.randint(1, 30))  # 현재로부터 1일에서 30일 이내의 미래 시간
    end_time = start_time + timedelta(days=random.randint(1, 30))  # start_time 이후 1일에서 30일 이내의 미래 시간
    return start_time.strftime('%Y-%m-%d'), end_time.strftime('%Y-%m-%d')

# 랜덤한 record_time 생성 함수
def generate_record_time():
    return (datetime.now() - timedelta(days=random.randint(0, 30))).strftime('%Y-%m-%d %H:%M:%S')  # 현재로부터 30일 이내의 과거 시간

# 랜덤한 데이터를 생성하는 함수
def generate_random_schedule_1_data(user_ids, num_records=100):
    data = {
        'user_id': [],
        'user_goal': [],
        'goal_complexity': [],
        'goal_start_time': [],
        'goal_end_time': [],
        'record_time': []
    }
    
    for _ in range(num_records):
        data['user_id'].append(random.choice(user_ids))  # user_id를 user_info의 user_id 중에서 랜덤 선택
        data['user_goal'].append(generate_user_goal())
        data['goal_complexity'].append(generate_goal_complexity())
        start_time, end_time = generate_goal_times()
        data['goal_start_time'].append(start_time)
        data['goal_end_time'].append(end_time)
        data['record_time'].append(generate_record_time())
    
    return pd.DataFrame(data)

# user_info의 user_id 목록을 변수로 저장
user_info_data = db.sql_query('SELECT user_id FROM user_info')
user_ids = [row['user_id'] for row in user_info_data]

# 데이터 생성
num_records = 100  # 생성할 레코드 수
schedule_1_data = generate_random_schedule_1_data(user_ids, num_records)

# 데이터 저장
save_data(schedule_1_data, 'schedule_1')
# Out:
# sql query :
#     INSERT INTO `schedule_1`
#     (user_id,user_goal,goal_complexity,goal_start_time,goal_end_time,record_time)
#     VALUES
#     (%s,%s,%s,%s,%s,%s)
#
# sql insert data :  {'user_id': '9KK0ANQ0er', 'user_goal': 'TSJUXTeYEK', 'goal_complexity': 1, 'goal_start_time': '2024-07-03', 'goal_end_time': '2024-07-16', 'record_time': '2024-05-30 18:46:30'}
# sql query :
#     INSERT INTO `schedule_1`
#     (user_id,user_goal,goal_complexity,goal_start_time,goal_end_time,record_time)
#     VALUES
#     (%s,%s,%s,%s,%s,%s)
#
# sql insert data :  {'user_id': 'MBWXRA6LXX', 'user_goal': 'PzPcEc35Qd', 'goal_complexity': 2, 'goal_start_time': '2024-07-16', 'goal_end_time': '2024-08-10', 'record_time': '2024-05-31 18:46:30'}
# sql query :
#     INSERT INTO `schedule_1`
#     (user_id,user_goal,goal_complexity,goal_start_time,goal_end_time,record_time)
#     VALUES
#     (%s,%s,%s,%s,%s,%s)
#
# sql insert data :  {'user_id': 'KUBsaCJpVG', 'user_goal': 'BAR98n4zZH', 'goal_complexity': 1, 'goal_start_time': '2024-07-15', 'goal_end_time': '2024-08-08', 'record_time': '2024-05-29 18:46:30'}
# sql query :
#     INSERT INTO `schedule_1`
#     (user_id,user_goal,goal_complexity,goal_start_time,goal_end_time,record_time)
#     VALUES
#     (%s,%s,%s,%s,%s,%s)
#
# sql insert data :  {'user_id': '8zjFTV6oWH', 'user_goal': 'NTIbtohd21', 'goal_complexity': 2, 'goal_start_time': '2024-07-18', 'goal_end_time': '2024-08-14', 'record_time': '2024-06-02 18:46:30'}
# sql query :
#     INSERT INTO `schedule_1`
#     (user_id,user_goal,goal_complexity,goal_start_time,goal_end_time,record_time)
#     VALUES
#     (%s,%s,%s,%s,%s,%s)
#
# sql insert data :  {'user_id': 'L1dVaEdeOM', 'user_goal': 'nSfst0jdu7', 'goal_complexity': 1, 'goal_start_time': '2024-07-05', 'goal_end_time': '2024-07-26', 'record_time': '2024-06-01 18:46:30'}
# sql query :
#     INSERT INTO `schedule_1`
#     (user_id,user_goal,goal_complexity,goal_start_time,goal_end_time,record_time)
#     VALUES
#     (%s,%s,%s,%s,%s,%s)
#
# sql insert data :  {'user_id': 'WZWZHNasYh', 'user_goal': 'IHOjXreels', 'goal_complexity': 2, 'goal_start_time': '2024-07-17', 'goal_end_time': '2024-08-10', 'record_time': '2024-06-02 18:46:30'}
# sql query :
#     INSERT INTO `schedule_1`
#     (user_id,user_goal,goal_complexity,goal_start_time,goal_end_time,record_time)
#     VALUES
#     (%s,%s,%s,%s,%s,%s)
#
# sql insert data :  {'user_id': 'KxrI5sYYU2', 'user_goal': '45GD3LqdTP', 'goal_complexity': 4, 'goal_start_time': '2024-07-05', 'goal_end_time': '2024-08-03', 'record_time': '2024-05-20 18:46:30'}
# sql query :
#     INSERT INTO `schedule_1`
#     (user_id,user_goal,goal_complexity,goal_start_time,goal_end_time,record_time)
#     VALUES
#     (%s,%s,%s,%s,%s,%s)
#
# sql insert data :  {'user_id': 'tD94MKul9N', 'user_goal': 'k5M2aeii72', 'goal_complexity': 5, 'goal_start_time': '2024-06-22', 'goal_end_time': '2024-07-04', 'record_time': '2024-06-03 18:46:30'}
# sql query :
#     INSERT INTO `schedule_1`
#     (user_id,user_goal,goal_complexity,goal_start_time,goal_end_time,record_time)
#     VALUES
#     (%s,%s,%s,%s,%s,%s)
#
# sql insert data :  {'user_id': 'DJ1IDo5hhb', 'user_goal': 'CFc5ibgPNU', 'goal_complexity': 1, 'goal_start_time': '2024-06-28', 'goal_end_time': '2024-07-23', 'record_time': '2024-05-20 18:46:30'}
# sql query :
#     INSERT INTO `schedule_1`
#     (user_id,user_goal,goal_complexity,goal_start_time,goal_end_time,record_time)
#     VALUES
#     (%s,%s,%s,%s,%s,%s)
#
# sql insert data :  {'user_id': 'ggOCYSJAXr', 'user_goal': 'mED24HmKXU', 'goal_complexity': 3, 'goal_start_time': '2024-06-29', 'goal_end_time': '2024-07-14', 'record_time': '2024-06-09 18:46:30'}
# sql query :
#     INSERT INTO `schedule_1`
#     (user_id,user_goal,goal_complexity,goal_start_time,goal_end_time,record_time)
#     VALUES
#     (%s,%s,%s,%s,%s,%s)
#
# sql insert data :  {'user_id': 'vX1RDnmedL', 'user_goal': 'YfRzW7WuF0', 'goal_complexity': 3, 'goal_start_time': '2024-07-13', 'goal_end_time': '2024-07-26', 'record_time': '2024-05-22 18:46:30'}
# sql query :
#     INSERT INTO `schedule_1`
#     (user_id,user_goal,goal_complexity,goal_start_time,goal_end_time,record_time)
#     VALUES
#     (%s,%s,%s,%s,%s,%s)
#
# sql insert data :  {'user_id': 'cd7Zun1Lqy', 'user_goal': 'yl1TJZExBl', 'goal_complexity': 5, 'goal_start_time': '2024-06-29', 'goal_end_time': '2024-07-20', 'record_time': '2024-06-17 18:46:30'}
# sql query :
#     INSERT INTO `schedule_1`
#     (user_id,user_goal,goal_complexity,goal_start_time,goal_end_time,record_time)
#     VALUES
#     (%s,%s,%s,%s,%s,%s)
#
# sql insert data :  {'user_id': 'wP08brQxiF', 'user_goal': 'PuPP1pAcPR', 'goal_complexity': 5, 'goal_start_time': '2024-07-16', 'goal_end_time': '2024-08-01', 'record_time': '2024-05-19 18:46:30'}
# sql query :
#     INSERT INTO `schedule_1`
#     (user_id,user_goal,goal_complexity,goal_start_time,goal_end_time,record_time)
#     VALUES
#     (%s,%s,%s,%s,%s,%s)
#
# sql insert data :  {'user_id': 'Ko6VsiGJZT', 'user_goal': 'Ewz0XxaEc0', 'goal_complexity': 4, 'goal_start_time': '2024-07-16', 'goal_end_time': '2024-08-05', 'record_time': '2024-05-19 18:46:30'}
# sql query :
#     INSERT INTO `schedule_1`
#     (user_id,user_goal,goal_complexity,goal_start_time,goal_end_time,record_time)
#     VALUES
#     (%s,%s,%s,%s,%s,%s)
#
# sql insert data :  {'user_id': '2EXSzl3J2n', 'user_goal': 'WJ8o9OhoC3', 'goal_complexity': 1, 'goal_start_time': '2024-06-21', 'goal_end_time': '2024-07-01', 'record_time': '2024-06-18 18:46:30'}
# sql query :
#     INSERT INTO `schedule_1`
#     (user_id,user_goal,goal_complexity,goal_start_time,goal_end_time,record_time)
#     VALUES
#     (%s,%s,%s,%s,%s,%s)
#
# sql insert data :  {'user_id': 'MwiTyS1cts', 'user_goal': 'GLJeYJKJAY', 'goal_complexity': 3, 'goal_start_time': '2024-07-15', 'goal_end_time': '2024-08-08', 'record_time': '2024-06-13 18:46:30'}
# sql query :
#     INSERT INTO `schedule_1`
#     (user_id,user_goal,goal_complexity,goal_start_time,goal_end_time,record_time)
#     VALUES
#     (%s,%s,%s,%s,%s,%s)
#
# sql insert data :  {'user_id': 'MBWXRA6LXX', 'user_goal': 'Nppt1OWege', 'goal_complexity': 5, 'goal_start_time': '2024-06-30', 'goal_end_time': '2024-07-08', 'record_time': '2024-06-13 18:46:30'}
# sql query :
#     INSERT INTO `schedule_1`
#     (user_id,user_goal,goal_complexity,goal_start_time,goal_end_time,record_time)
#     VALUES
#     (%s,%s,%s,%s,%s,%s)
#
# sql insert data :  {'user_id': 'LV1U2eC0NE', 'user_goal': 'TRJJuiRbps', 'goal_complexity': 2, 'goal_start_time': '2024-06-21', 'goal_end_time': '2024-07-16', 'record_time': '2024-05-23 18:46:30'}
# sql query :
#     INSERT INTO `schedule_1`
#     (user_id,user_goal,goal_complexity,goal_start_time,goal_end_time,record_time)
#     VALUES
#     (%s,%s,%s,%s,%s,%s)
#
# sql insert data :  {'user_id': 'NI9Z4NleiX', 'user_goal': 'om5VqWIeD5', 'goal_complexity': 4, 'goal_start_time': '2024-07-05', 'goal_end_time': '2024-07-31', 'record_time': '2024-06-12 18:46:30'}
# sql query :
#     INSERT INTO `schedule_1`
#     (user_id,user_goal,goal_complexity,goal_start_time,goal_end_time,record_time)
#     VALUES
#     (%s,%s,%s,%s,%s,%s)
#
# sql insert data :  {'user_id': '6lUwtVLF1x', 'user_goal': '5ehYWyS8hw', 'goal_complexity': 3, 'goal_start_time': '2024-07-03', 'goal_end_time': '2024-07-21', 'record_time': '2024-06-08 18:46:30'}
# sql query :
#     INSERT INTO `schedule_1`
#     (user_id,user_goal,goal_complexity,goal_start_time,goal_end_time,record_time)
#     VALUES
#     (%s,%s,%s,%s,%s,%s)
#
# sql insert data :  {'user_id': '16JjaqECe0', 'user_goal': 'mf9PAX898m', 'goal_complexity': 2, 'goal_start_time': '2024-07-09', 'goal_end_time': '2024-07-26', 'record_time': '2024-06-17 18:46:30'}
# sql query :
#     INSERT INTO `schedule_1`
#     (user_id,user_goal,goal_complexity,goal_start_time,goal_end_time,record_time)
#     VALUES
#     (%s,%s,%s,%s,%s,%s)
#
# sql insert data :  {'user_id': '16JjaqECe0', 'user_goal': 'rAQyLAnAE8', 'goal_complexity': 5, 'goal_start_time': '2024-06-30', 'goal_end_time': '2024-07-20', 'record_time': '2024-06-12 18:46:30'}
# sql query :
#     INSERT INTO `schedule_1`
#     (user_id,user_goal,goal_complexity,goal_start_time,goal_end_time,record_time)
#     VALUES
#     (%s,%s,%s,%s,%s,%s)
#
# sql insert data :  {'user_id': '9KK0ANQ0er', 'user_goal': 'tUOETFodiP', 'goal_complexity': 1, 'goal_start_time': '2024-07-18', 'goal_end_time': '2024-08-10', 'record_time': '2024-06-14 18:46:30'}
# sql query :
#     INSERT INTO `schedule_1`
#     (user_id,user_goal,goal_complexity,goal_start_time,goal_end_time,record_time)
#     VALUES
#     (%s,%s,%s,%s,%s,%s)
#
# sql insert data :  {'user_id': 'NI9Z4NleiX', 'user_goal': 'vpBGmZw5qN', 'goal_complexity': 4, 'goal_start_time': '2024-07-05', 'goal_end_time': '2024-07-18', 'record_time': '2024-05-23 18:46:30'}
# sql query :
#     INSERT INTO `schedule_1`
#     (user_id,user_goal,goal_complexity,goal_start_time,goal_end_time,record_time)
#     VALUES
#     (%s,%s,%s,%s,%s,%s)
#
# sql insert data :  {'user_id': 'NI9Z4NleiX', 'user_goal': 'FYRuecYoEy', 'goal_complexity': 3, 'goal_start_time': '2024-07-07', 'goal_end_time': '2024-07-11', 'record_time': '2024-05-27 18:46:30'}
# sql query :
#     INSERT INTO `schedule_1`
#     (user_id,user_goal,goal_complexity,goal_start_time,goal_end_time,record_time)
#     VALUES
#     (%s,%s,%s,%s,%s,%s)
#
# sql insert data :  {'user_id': 'nBXUT5XOxB', 'user_goal': '4YZI8YUzj9', 'goal_complexity': 3, 'goal_start_time': '2024-06-29', 'goal_end_time': '2024-07-05', 'record_time': '2024-06-03 18:46:30'}
# sql query :
#     INSERT INTO `schedule_1`
#     (user_id,user_goal,goal_complexity,goal_start_time,goal_end_time,record_time)
#     VALUES
#     (%s,%s,%s,%s,%s,%s)
#
# sql insert data :  {'user_id': 'H0HvUePjPD', 'user_goal': 'pvpbzqUNSB', 'goal_complexity': 4, 'goal_start_time': '2024-07-13', 'goal_end_time': '2024-07-22', 'record_time': '2024-06-13 18:46:30'}
# sql query :
#     INSERT INTO `schedule_1`
#     (user_id,user_goal,goal_complexity,goal_start_time,goal_end_time,record_time)
#     VALUES
#     (%s,%s,%s,%s,%s,%s)
#
# sql insert data :  {'user_id': 'ejqet4vWpk', 'user_goal': 'hOkHjOjXv4', 'goal_complexity': 3, 'goal_start_time': '2024-07-10', 'goal_end_time': '2024-07-27', 'record_time': '2024-05-23 18:46:30'}
# sql query :
#     INSERT INTO `schedule_1`
#     (user_id,user_goal,goal_complexity,goal_start_time,goal_end_time,record_time)
#     VALUES
#     (%s,%s,%s,%s,%s,%s)
#
# sql insert data :  {'user_id': 'vX1RDnmedL', 'user_goal': 'rsOE2RYu27', 'goal_complexity': 3, 'goal_start_time': '2024-07-07', 'goal_end_time': '2024-07-13', 'record_time': '2024-05-19 18:46:30'}
# sql query :
#     INSERT INTO `schedule_1`
#     (user_id,user_goal,goal_complexity,goal_start_time,goal_end_time,record_time)
#     VALUES
#     (%s,%s,%s,%s,%s,%s)
#
# sql insert data :  {'user_id': '2hA7gtu1Ug', 'user_goal': 'ldCbM1fYmW', 'goal_complexity': 5, 'goal_start_time': '2024-07-08', 'goal_end_time': '2024-07-17', 'record_time': '2024-06-18 18:46:30'}
# sql query :
#     INSERT INTO `schedule_1`
#     (user_id,user_goal,goal_complexity,goal_start_time,goal_end_time,record_time)
#     VALUES
#     (%s,%s,%s,%s,%s,%s)
#
# sql insert data :  {'user_id': 'FmKH3PyrrP', 'user_goal': '59hCWSDg88', 'goal_complexity': 3, 'goal_start_time': '2024-06-19', 'goal_end_time': '2024-07-12', 'record_time': '2024-05-29 18:46:30'}
# sql query :
#     INSERT INTO `schedule_1`
#     (user_id,user_goal,goal_complexity,goal_start_time,goal_end_time,record_time)
#     VALUES
#     (%s,%s,%s,%s,%s,%s)
#
# sql insert data :  {'user_id': '9pP99ckY3b', 'user_goal': '87F5qt9kLY', 'goal_complexity': 1, 'goal_start_time': '2024-06-29', 'goal_end_time': '2024-07-04', 'record_time': '2024-06-06 18:46:30'}
# sql query :
#     INSERT INTO `schedule_1`
#     (user_id,user_goal,goal_complexity,goal_start_time,goal_end_time,record_time)
#     VALUES
#     (%s,%s,%s,%s,%s,%s)
#
# sql insert data :  {'user_id': 'RV3ix4DmCH', 'user_goal': 'oyxRTHURfp', 'goal_complexity': 1, 'goal_start_time': '2024-07-11', 'goal_end_time': '2024-07-27', 'record_time': '2024-06-18 18:46:30'}
# sql query :
#     INSERT INTO `schedule_1`
#     (user_id,user_goal,goal_complexity,goal_start_time,goal_end_time,record_time)
#     VALUES
#     (%s,%s,%s,%s,%s,%s)
#
# sql insert data :  {'user_id': 'DeCpYXYkM0', 'user_goal': 'W4vFus044l', 'goal_complexity': 2, 'goal_start_time': '2024-07-02', 'goal_end_time': '2024-07-18', 'record_time': '2024-05-19 18:46:30'}
# sql query :
#     INSERT INTO `schedule_1`
#     (user_id,user_goal,goal_complexity,goal_start_time,goal_end_time,record_time)
#     VALUES
#     (%s,%s,%s,%s,%s,%s)
#
# sql insert data :  {'user_id': 'yxhXTCcBLE', 'user_goal': 'YOtfYfzEe0', 'goal_complexity': 2, 'goal_start_time': '2024-07-14', 'goal_end_time': '2024-08-05', 'record_time': '2024-05-19 18:46:30'}
# sql query :
#     INSERT INTO `schedule_1`
#     (user_id,user_goal,goal_complexity,goal_start_time,goal_end_time,record_time)
#     VALUES
#     (%s,%s,%s,%s,%s,%s)
#
# sql insert data :  {'user_id': '9pP99ckY3b', 'user_goal': 'PmPH10jXko', 'goal_complexity': 1, 'goal_start_time': '2024-07-18', 'goal_end_time': '2024-08-16', 'record_time': '2024-05-29 18:46:30'}
# sql query :
#     INSERT INTO `schedule_1`
#     (user_id,user_goal,goal_complexity,goal_start_time,goal_end_time,record_time)
#     VALUES
#     (%s,%s,%s,%s,%s,%s)
#
# sql insert data :  {'user_id': 'qYwc2HhSzI', 'user_goal': 'F7OpHNsoaE', 'goal_complexity': 2, 'goal_start_time': '2024-07-10', 'goal_end_time': '2024-07-28', 'record_time': '2024-05-28 18:46:30'}
# sql query :
#     INSERT INTO `schedule_1`
#     (user_id,user_goal,goal_complexity,goal_start_time,goal_end_time,record_time)
#     VALUES
#     (%s,%s,%s,%s,%s,%s)
#
# sql insert data :  {'user_id': 'ZHLvRB0aN6', 'user_goal': 'Sl8WcjGm7a', 'goal_complexity': 1, 'goal_start_time': '2024-07-06', 'goal_end_time': '2024-07-12', 'record_time': '2024-05-19 18:46:30'}
# sql query :
#     INSERT INTO `schedule_1`
#     (user_id,user_goal,goal_complexity,goal_start_time,goal_end_time,record_time)
#     VALUES
#     (%s,%s,%s,%s,%s,%s)
#
# sql insert data :  {'user_id': 'Spo08mb51d', 'user_goal': 'lfC6RcJTdD', 'goal_complexity': 4, 'goal_start_time': '2024-06-30', 'goal_end_time': '2024-07-23', 'record_time': '2024-05-29 18:46:30'}
# sql query :
#     INSERT INTO `schedule_1`
#     (user_id,user_goal,goal_complexity,goal_start_time,goal_end_time,record_time)
#     VALUES
#     (%s,%s,%s,%s,%s,%s)
#
# sql insert data :  {'user_id': '1ZzKVMEwFf', 'user_goal': 'D6XETtu1Lf', 'goal_complexity': 2, 'goal_start_time': '2024-07-14', 'goal_end_time': '2024-07-21', 'record_time': '2024-06-16 18:46:30'}
# sql query :
#     INSERT INTO `schedule_1`
#     (user_id,user_goal,goal_complexity,goal_start_time,goal_end_time,record_time)
#     VALUES
#     (%s,%s,%s,%s,%s,%s)
#
# sql insert data :  {'user_id': 'vX1RDnmedL', 'user_goal': 'qaqnfLNpG5', 'goal_complexity': 4, 'goal_start_time': '2024-06-19', 'goal_end_time': '2024-07-01', 'record_time': '2024-06-01 18:46:30'}
# sql query :
#     INSERT INTO `schedule_1`
#     (user_id,user_goal,goal_complexity,goal_start_time,goal_end_time,record_time)
#     VALUES
#     (%s,%s,%s,%s,%s,%s)
#
# sql insert data :  {'user_id': '5HMgqUqQIU', 'user_goal': 'tkfLhEld0G', 'goal_complexity': 5, 'goal_start_time': '2024-07-01', 'goal_end_time': '2024-07-30', 'record_time': '2024-05-21 18:46:30'}
# sql query :
#     INSERT INTO `schedule_1`
#     (user_id,user_goal,goal_complexity,goal_start_time,goal_end_time,record_time)
#     VALUES
#     (%s,%s,%s,%s,%s,%s)
#
# sql insert data :  {'user_id': 'ejqet4vWpk', 'user_goal': '8oQX0pm7Co', 'goal_complexity': 2, 'goal_start_time': '2024-07-16', 'goal_end_time': '2024-08-14', 'record_time': '2024-06-06 18:46:30'}
# sql query :
#     INSERT INTO `schedule_1`
#     (user_id,user_goal,goal_complexity,goal_start_time,goal_end_time,record_time)
#     VALUES
#     (%s,%s,%s,%s,%s,%s)
#
# sql insert data :  {'user_id': 'DeCpYXYkM0', 'user_goal': 'YVuF4mH5bY', 'goal_complexity': 3, 'goal_start_time': '2024-07-02', 'goal_end_time': '2024-07-25', 'record_time': '2024-05-28 18:46:30'}
# sql query :
#     INSERT INTO `schedule_1`
#     (user_id,user_goal,goal_complexity,goal_start_time,goal_end_time,record_time)
#     VALUES
#     (%s,%s,%s,%s,%s,%s)
#
# sql insert data :  {'user_id': 'VppjgLKbJn', 'user_goal': 'MQVzkPBvWH', 'goal_complexity': 2, 'goal_start_time': '2024-06-29', 'goal_end_time': '2024-07-14', 'record_time': '2024-05-31 18:46:30'}
# sql query :
#     INSERT INTO `schedule_1`
#     (user_id,user_goal,goal_complexity,goal_start_time,goal_end_time,record_time)
#     VALUES
#     (%s,%s,%s,%s,%s,%s)
#
# sql insert data :  {'user_id': 'YH85B7na01', 'user_goal': 'Bm2vIKUCDQ', 'goal_complexity': 2, 'goal_start_time': '2024-06-19', 'goal_end_time': '2024-06-23', 'record_time': '2024-06-07 18:46:30'}
# sql query :
#     INSERT INTO `schedule_1`
#     (user_id,user_goal,goal_complexity,goal_start_time,goal_end_time,record_time)
#     VALUES
#     (%s,%s,%s,%s,%s,%s)
#
# sql insert data :  {'user_id': 'sosG3KPxWz', 'user_goal': 'atEVk2eaU4', 'goal_complexity': 2, 'goal_start_time': '2024-06-30', 'goal_end_time': '2024-07-02', 'record_time': '2024-06-18 18:46:30'}
# sql query :
#     INSERT INTO `schedule_1`
#     (user_id,user_goal,goal_complexity,goal_start_time,goal_end_time,record_time)
#     VALUES
#     (%s,%s,%s,%s,%s,%s)
#
# sql insert data :  {'user_id': 'yzgLKdJpEq', 'user_goal': 'TTPJ3v1AoM', 'goal_complexity': 1, 'goal_start_time': '2024-07-11', 'goal_end_time': '2024-07-18', 'record_time': '2024-05-31 18:46:30'}
# sql query :
#     INSERT INTO `schedule_1`
#     (user_id,user_goal,goal_complexity,goal_start_time,goal_end_time,record_time)
#     VALUES
#     (%s,%s,%s,%s,%s,%s)
#
# sql insert data :  {'user_id': 'CRn9S2xsD5', 'user_goal': '1g4T5QtB9d', 'goal_complexity': 5, 'goal_start_time': '2024-07-18', 'goal_end_time': '2024-07-27', 'record_time': '2024-06-04 18:46:30'}
# sql query :
#     INSERT INTO `schedule_1`
#     (user_id,user_goal,goal_complexity,goal_start_time,goal_end_time,record_time)
#     VALUES
#     (%s,%s,%s,%s,%s,%s)
#
# sql insert data :  {'user_id': '0YttYPfeRQ', 'user_goal': 'qg3IOG7tTb', 'goal_complexity': 4, 'goal_start_time': '2024-06-30', 'goal_end_time': '2024-07-08', 'record_time': '2024-05-31 18:46:30'}
# sql query :
#     INSERT INTO `schedule_1`
#     (user_id,user_goal,goal_complexity,goal_start_time,goal_end_time,record_time)
#     VALUES
#     (%s,%s,%s,%s,%s,%s)
#
# sql insert data :  {'user_id': 'LtMa0Z0R09', 'user_goal': 'BXYTfGOjlQ', 'goal_complexity': 4, 'goal_start_time': '2024-06-28', 'goal_end_time': '2024-07-15', 'record_time': '2024-06-04 18:46:30'}
# sql query :
#     INSERT INTO `schedule_1`
#     (user_id,user_goal,goal_complexity,goal_start_time,goal_end_time,record_time)
#     VALUES
#     (%s,%s,%s,%s,%s,%s)
#
# sql insert data :  {'user_id': 'RgATnk21js', 'user_goal': 'xRS6C1OZKW', 'goal_complexity': 2, 'goal_start_time': '2024-07-18', 'goal_end_time': '2024-08-07', 'record_time': '2024-05-20 18:46:30'}
# sql query :
#     INSERT INTO `schedule_1`
#     (user_id,user_goal,goal_complexity,goal_start_time,goal_end_time,record_time)
#     VALUES
#     (%s,%s,%s,%s,%s,%s)
#
# sql insert data :  {'user_id': 'omjVtjXIxD', 'user_goal': 's83aY5xEay', 'goal_complexity': 3, 'goal_start_time': '2024-06-26', 'goal_end_time': '2024-07-26', 'record_time': '2024-06-03 18:46:30'}
# sql query :
#     INSERT INTO `schedule_1`
#     (user_id,user_goal,goal_complexity,goal_start_time,goal_end_time,record_time)
#     VALUES
#     (%s,%s,%s,%s,%s,%s)
#
# sql insert data :  {'user_id': 'XXY2fc1aRj', 'user_goal': 'sbIpctyYMC', 'goal_complexity': 3, 'goal_start_time': '2024-06-19', 'goal_end_time': '2024-07-02', 'record_time': '2024-05-26 18:46:30'}
# sql query :
#     INSERT INTO `schedule_1`
#     (user_id,user_goal,goal_complexity,goal_start_time,goal_end_time,record_time)
#     VALUES
#     (%s,%s,%s,%s,%s,%s)
#
# sql insert data :  {'user_id': 'xA3NQznPmp', 'user_goal': 'OMojKpJ5BK', 'goal_complexity': 2, 'goal_start_time': '2024-07-01', 'goal_end_time': '2024-07-04', 'record_time': '2024-05-30 18:46:30'}
# sql query :
#     INSERT INTO `schedule_1`
#     (user_id,user_goal,goal_complexity,goal_start_time,goal_end_time,record_time)
#     VALUES
#     (%s,%s,%s,%s,%s,%s)
#
# sql insert data :  {'user_id': 'vX1RDnmedL', 'user_goal': '0DMQAKfF03', 'goal_complexity': 3, 'goal_start_time': '2024-06-24', 'goal_end_time': '2024-07-12', 'record_time': '2024-05-31 18:46:30'}
# sql query :
#     INSERT INTO `schedule_1`
#     (user_id,user_goal,goal_complexity,goal_start_time,goal_end_time,record_time)
#     VALUES
#     (%s,%s,%s,%s,%s,%s)
#
# sql insert data :  {'user_id': 'fuDoEnxHs9', 'user_goal': '7GP33a9dM7', 'goal_complexity': 4, 'goal_start_time': '2024-06-23', 'goal_end_time': '2024-07-19', 'record_time': '2024-06-16 18:46:30'}
# sql query :
#     INSERT INTO `schedule_1`
#     (user_id,user_goal,goal_complexity,goal_start_time,goal_end_time,record_time)
#     VALUES
#     (%s,%s,%s,%s,%s,%s)
#
# sql insert data :  {'user_id': 'YKnt0SIvSb', 'user_goal': 'DK4f5Es5F5', 'goal_complexity': 2, 'goal_start_time': '2024-07-03', 'goal_end_time': '2024-08-01', 'record_time': '2024-05-29 18:46:30'}
# sql query :
#     INSERT INTO `schedule_1`
#     (user_id,user_goal,goal_complexity,goal_start_time,goal_end_time,record_time)
#     VALUES
#     (%s,%s,%s,%s,%s,%s)
#
# sql insert data :  {'user_id': 'ngaTkjk7B9', 'user_goal': 'BkePs7urvJ', 'goal_complexity': 2, 'goal_start_time': '2024-07-13', 'goal_end_time': '2024-08-09', 'record_time': '2024-06-18 18:46:30'}
# sql query :
#     INSERT INTO `schedule_1`
#     (user_id,user_goal,goal_complexity,goal_start_time,goal_end_time,record_time)
#     VALUES
#     (%s,%s,%s,%s,%s,%s)
#
# sql insert data :  {'user_id': 'tD94MKul9N', 'user_goal': 'YQBF5CoGa7', 'goal_complexity': 3, 'goal_start_time': '2024-07-12', 'goal_end_time': '2024-07-17', 'record_time': '2024-05-26 18:46:30'}
# sql query :
#     INSERT INTO `schedule_1`
#     (user_id,user_goal,goal_complexity,goal_start_time,goal_end_time,record_time)
#     VALUES
#     (%s,%s,%s,%s,%s,%s)
#
# sql insert data :  {'user_id': 'dpOmGjRkIo', 'user_goal': 'fgv2ssitcF', 'goal_complexity': 4, 'goal_start_time': '2024-06-24', 'goal_end_time': '2024-07-02', 'record_time': '2024-05-19 18:46:30'}
# sql query :
#     INSERT INTO `schedule_1`
#     (user_id,user_goal,goal_complexity,goal_start_time,goal_end_time,record_time)
#     VALUES
#     (%s,%s,%s,%s,%s,%s)
#
# sql insert data :  {'user_id': 'SSN6iN98qH', 'user_goal': 'l49onwGzVy', 'goal_complexity': 1, 'goal_start_time': '2024-07-16', 'goal_end_time': '2024-07-28', 'record_time': '2024-05-30 18:46:30'}
# sql query :
#     INSERT INTO `schedule_1`
#     (user_id,user_goal,goal_complexity,goal_start_time,goal_end_time,record_time)
#     VALUES
#     (%s,%s,%s,%s,%s,%s)
#
# sql insert data :  {'user_id': 'omjVtjXIxD', 'user_goal': 'EPmCIXwXg6', 'goal_complexity': 5, 'goal_start_time': '2024-07-11', 'goal_end_time': '2024-07-15', 'record_time': '2024-06-08 18:46:30'}
# sql query :
#     INSERT INTO `schedule_1`
#     (user_id,user_goal,goal_complexity,goal_start_time,goal_end_time,record_time)
#     VALUES
#     (%s,%s,%s,%s,%s,%s)
#
# sql insert data :  {'user_id': 'sosG3KPxWz', 'user_goal': 'Js1AySsFaC', 'goal_complexity': 5, 'goal_start_time': '2024-07-01', 'goal_end_time': '2024-07-19', 'record_time': '2024-06-03 18:46:30'}
# sql query :
#     INSERT INTO `schedule_1`
#     (user_id,user_goal,goal_complexity,goal_start_time,goal_end_time,record_time)
#     VALUES
#     (%s,%s,%s,%s,%s,%s)
#
# sql insert data :  {'user_id': 'MxODNuYnKs', 'user_goal': 'UNJKH2TRxL', 'goal_complexity': 4, 'goal_start_time': '2024-06-29', 'goal_end_time': '2024-07-22', 'record_time': '2024-06-04 18:46:30'}
# sql query :
#     INSERT INTO `schedule_1`
#     (user_id,user_goal,goal_complexity,goal_start_time,goal_end_time,record_time)
#     VALUES
#     (%s,%s,%s,%s,%s,%s)
#
# sql insert data :  {'user_id': 'YH85B7na01', 'user_goal': 'dr0eo2wsvm', 'goal_complexity': 5, 'goal_start_time': '2024-07-11', 'goal_end_time': '2024-07-31', 'record_time': '2024-05-22 18:46:30'}
# sql query :
#     INSERT INTO `schedule_1`
#     (user_id,user_goal,goal_complexity,goal_start_time,goal_end_time,record_time)
#     VALUES
#     (%s,%s,%s,%s,%s,%s)
#
# sql insert data :  {'user_id': 'CRn9S2xsD5', 'user_goal': 'jFs9qphviv', 'goal_complexity': 4, 'goal_start_time': '2024-06-25', 'goal_end_time': '2024-07-10', 'record_time': '2024-05-27 18:46:30'}
# sql query :
#     INSERT INTO `schedule_1`
#     (user_id,user_goal,goal_complexity,goal_start_time,goal_end_time,record_time)
#     VALUES
#     (%s,%s,%s,%s,%s,%s)
#
# sql insert data :  {'user_id': 'VppjgLKbJn', 'user_goal': 'BxnNJCoyGr', 'goal_complexity': 2, 'goal_start_time': '2024-07-16', 'goal_end_time': '2024-07-29', 'record_time': '2024-06-04 18:46:30'}
# sql query :
#     INSERT INTO `schedule_1`
#     (user_id,user_goal,goal_complexity,goal_start_time,goal_end_time,record_time)
#     VALUES
#     (%s,%s,%s,%s,%s,%s)
#
# sql insert data :  {'user_id': 'yzgLKdJpEq', 'user_goal': 'pJUwruSBsu', 'goal_complexity': 2, 'goal_start_time': '2024-07-08', 'goal_end_time': '2024-07-14', 'record_time': '2024-05-20 18:46:30'}
# sql query :
#     INSERT INTO `schedule_1`
#     (user_id,user_goal,goal_complexity,goal_start_time,goal_end_time,record_time)
#     VALUES
#     (%s,%s,%s,%s,%s,%s)
#
# sql insert data :  {'user_id': '2EXSzl3J2n', 'user_goal': 'Q3RynYDaIw', 'goal_complexity': 3, 'goal_start_time': '2024-06-19', 'goal_end_time': '2024-06-20', 'record_time': '2024-06-06 18:46:30'}
# sql query :
#     INSERT INTO `schedule_1`
#     (user_id,user_goal,goal_complexity,goal_start_time,goal_end_time,record_time)
#     VALUES
#     (%s,%s,%s,%s,%s,%s)
#
# sql insert data :  {'user_id': 'DJ1IDo5hhb', 'user_goal': 'EekkiD01a5', 'goal_complexity': 4, 'goal_start_time': '2024-06-23', 'goal_end_time': '2024-07-16', 'record_time': '2024-06-17 18:46:30'}
# sql query :
#     INSERT INTO `schedule_1`
#     (user_id,user_goal,goal_complexity,goal_start_time,goal_end_time,record_time)
#     VALUES
#     (%s,%s,%s,%s,%s,%s)
#
# sql insert data :  {'user_id': '6lUwtVLF1x', 'user_goal': 'sg5rDUV2fO', 'goal_complexity': 4, 'goal_start_time': '2024-07-17', 'goal_end_time': '2024-07-20', 'record_time': '2024-06-12 18:46:30'}
# sql query :
#     INSERT INTO `schedule_1`
#     (user_id,user_goal,goal_complexity,goal_start_time,goal_end_time,record_time)
#     VALUES
#     (%s,%s,%s,%s,%s,%s)
#
# sql insert data :  {'user_id': 'qYwc2HhSzI', 'user_goal': 'yzf6BJSXaW', 'goal_complexity': 2, 'goal_start_time': '2024-06-26', 'goal_end_time': '2024-07-02', 'record_time': '2024-06-08 18:46:30'}
# sql query :
#     INSERT INTO `schedule_1`
#     (user_id,user_goal,goal_complexity,goal_start_time,goal_end_time,record_time)
#     VALUES
#     (%s,%s,%s,%s,%s,%s)
#
# sql insert data :  {'user_id': 'MxODNuYnKs', 'user_goal': 'dHKrmyJqoa', 'goal_complexity': 3, 'goal_start_time': '2024-07-10', 'goal_end_time': '2024-07-11', 'record_time': '2024-05-21 18:46:30'}
# sql query :
#     INSERT INTO `schedule_1`
#     (user_id,user_goal,goal_complexity,goal_start_time,goal_end_time,record_time)
#     VALUES
#     (%s,%s,%s,%s,%s,%s)
#
# sql insert data :  {'user_id': 'xA3NQznPmp', 'user_goal': 'QIBntD9htn', 'goal_complexity': 3, 'goal_start_time': '2024-06-26', 'goal_end_time': '2024-07-15', 'record_time': '2024-05-22 18:46:30'}
# sql query :
#     INSERT INTO `schedule_1`
#     (user_id,user_goal,goal_complexity,goal_start_time,goal_end_time,record_time)
#     VALUES
#     (%s,%s,%s,%s,%s,%s)
#
# sql insert data :  {'user_id': '2hA7gtu1Ug', 'user_goal': 'FDik1hW2Wz', 'goal_complexity': 2, 'goal_start_time': '2024-06-27', 'goal_end_time': '2024-07-08', 'record_time': '2024-05-20 18:46:30'}
# sql query :
#     INSERT INTO `schedule_1`
#     (user_id,user_goal,goal_complexity,goal_start_time,goal_end_time,record_time)
#     VALUES
#     (%s,%s,%s,%s,%s,%s)
#
# sql insert data :  {'user_id': 'IbJwGXYYY3', 'user_goal': 'ueQEHhRHoN', 'goal_complexity': 4, 'goal_start_time': '2024-07-10', 'goal_end_time': '2024-08-02', 'record_time': '2024-06-12 18:46:30'}
# sql query :
#     INSERT INTO `schedule_1`
#     (user_id,user_goal,goal_complexity,goal_start_time,goal_end_time,record_time)
#     VALUES
#     (%s,%s,%s,%s,%s,%s)
#
# sql insert data :  {'user_id': 'yxhXTCcBLE', 'user_goal': 'hqygAp35mH', 'goal_complexity': 2, 'goal_start_time': '2024-07-09', 'goal_end_time': '2024-07-29', 'record_time': '2024-06-09 18:46:30'}
# sql query :
#     INSERT INTO `schedule_1`
#     (user_id,user_goal,goal_complexity,goal_start_time,goal_end_time,record_time)
#     VALUES
#     (%s,%s,%s,%s,%s,%s)
#
# sql insert data :  {'user_id': 'MxODNuYnKs', 'user_goal': 'cacTjKbLft', 'goal_complexity': 2, 'goal_start_time': '2024-06-23', 'goal_end_time': '2024-07-06', 'record_time': '2024-05-31 18:46:30'}
# sql query :
#     INSERT INTO `schedule_1`
#     (user_id,user_goal,goal_complexity,goal_start_time,goal_end_time,record_time)
#     VALUES
#     (%s,%s,%s,%s,%s,%s)
#
# sql insert data :  {'user_id': 'yzgLKdJpEq', 'user_goal': '1RTieRoJWI', 'goal_complexity': 5, 'goal_start_time': '2024-07-07', 'goal_end_time': '2024-07-16', 'record_time': '2024-05-29 18:46:30'}
# sql query :
#     INSERT INTO `schedule_1`
#     (user_id,user_goal,goal_complexity,goal_start_time,goal_end_time,record_time)
#     VALUES
#     (%s,%s,%s,%s,%s,%s)
#
# sql insert data :  {'user_id': '5HMgqUqQIU', 'user_goal': 'hkkYUHFTWF', 'goal_complexity': 5, 'goal_start_time': '2024-07-05', 'goal_end_time': '2024-07-29', 'record_time': '2024-05-28 18:46:30'}
# sql query :
#     INSERT INTO `schedule_1`
#     (user_id,user_goal,goal_complexity,goal_start_time,goal_end_time,record_time)
#     VALUES
#     (%s,%s,%s,%s,%s,%s)
#
# sql insert data :  {'user_id': 'aioQCDcjmI', 'user_goal': 'uFBDFywDzv', 'goal_complexity': 1, 'goal_start_time': '2024-06-20', 'goal_end_time': '2024-07-17', 'record_time': '2024-06-01 18:46:30'}
# sql query :
#     INSERT INTO `schedule_1`
#     (user_id,user_goal,goal_complexity,goal_start_time,goal_end_time,record_time)
#     VALUES
#     (%s,%s,%s,%s,%s,%s)
#
# sql insert data :  {'user_id': 'aioQCDcjmI', 'user_goal': 'pqWyLFVKMr', 'goal_complexity': 5, 'goal_start_time': '2024-06-22', 'goal_end_time': '2024-07-16', 'record_time': '2024-06-10 18:46:30'}
# sql query :
#     INSERT INTO `schedule_1`
#     (user_id,user_goal,goal_complexity,goal_start_time,goal_end_time,record_time)
#     VALUES
#     (%s,%s,%s,%s,%s,%s)
#
# sql insert data :  {'user_id': '9CFGTbD6IL', 'user_goal': 'BeA33Sreo9', 'goal_complexity': 2, 'goal_start_time': '2024-07-10', 'goal_end_time': '2024-07-21', 'record_time': '2024-05-19 18:46:30'}
# sql query :
#     INSERT INTO `schedule_1`
#     (user_id,user_goal,goal_complexity,goal_start_time,goal_end_time,record_time)
#     VALUES
#     (%s,%s,%s,%s,%s,%s)
#
# sql insert data :  {'user_id': '8zjFTV6oWH', 'user_goal': 'XyECL74BFN', 'goal_complexity': 4, 'goal_start_time': '2024-07-05', 'goal_end_time': '2024-07-21', 'record_time': '2024-06-14 18:46:30'}
# sql query :
#     INSERT INTO `schedule_1`
#     (user_id,user_goal,goal_complexity,goal_start_time,goal_end_time,record_time)
#     VALUES
#     (%s,%s,%s,%s,%s,%s)
#
# sql insert data :  {'user_id': 'GqveETW8N2', 'user_goal': 'Uo4roJyWKL', 'goal_complexity': 2, 'goal_start_time': '2024-06-26', 'goal_end_time': '2024-07-14', 'record_time': '2024-06-02 18:46:30'}
# sql query :
#     INSERT INTO `schedule_1`
#     (user_id,user_goal,goal_complexity,goal_start_time,goal_end_time,record_time)
#     VALUES
#     (%s,%s,%s,%s,%s,%s)
#
# sql insert data :  {'user_id': 'oGpjf9mBqU', 'user_goal': '2UFeqWLirO', 'goal_complexity': 4, 'goal_start_time': '2024-06-24', 'goal_end_time': '2024-07-14', 'record_time': '2024-06-02 18:46:30'}
# sql query :
#     INSERT INTO `schedule_1`
#     (user_id,user_goal,goal_complexity,goal_start_time,goal_end_time,record_time)
#     VALUES
#     (%s,%s,%s,%s,%s,%s)
#
# sql insert data :  {'user_id': 'sosG3KPxWz', 'user_goal': 'CF8PaJJdLP', 'goal_complexity': 1, 'goal_start_time': '2024-06-30', 'goal_end_time': '2024-07-05', 'record_time': '2024-06-09 18:46:30'}
# sql query :
#     INSERT INTO `schedule_1`
#     (user_id,user_goal,goal_complexity,goal_start_time,goal_end_time,record_time)
#     VALUES
#     (%s,%s,%s,%s,%s,%s)
#
# sql insert data :  {'user_id': 'xA3NQznPmp', 'user_goal': 'hQl1EAxIR8', 'goal_complexity': 3, 'goal_start_time': '2024-06-30', 'goal_end_time': '2024-07-24', 'record_time': '2024-06-11 18:46:30'}
# sql query :
#     INSERT INTO `schedule_1`
#     (user_id,user_goal,goal_complexity,goal_start_time,goal_end_time,record_time)
#     VALUES
#     (%s,%s,%s,%s,%s,%s)
#
# sql insert data :  {'user_id': '9CFGTbD6IL', 'user_goal': '9d3m0NvG4e', 'goal_complexity': 3, 'goal_start_time': '2024-07-11', 'goal_end_time': '2024-08-04', 'record_time': '2024-05-23 18:46:30'}
# sql query :
#     INSERT INTO `schedule_1`
#     (user_id,user_goal,goal_complexity,goal_start_time,goal_end_time,record_time)
#     VALUES
#     (%s,%s,%s,%s,%s,%s)
#
# sql insert data :  {'user_id': 'CRn9S2xsD5', 'user_goal': '1jifnSVyl2', 'goal_complexity': 1, 'goal_start_time': '2024-07-13', 'goal_end_time': '2024-07-18', 'record_time': '2024-05-29 18:46:30'}
# sql query :
#     INSERT INTO `schedule_1`
#     (user_id,user_goal,goal_complexity,goal_start_time,goal_end_time,record_time)
#     VALUES
#     (%s,%s,%s,%s,%s,%s)
#
# sql insert data :  {'user_id': 'qYwc2HhSzI', 'user_goal': '2L6wmXIsIp', 'goal_complexity': 3, 'goal_start_time': '2024-06-27', 'goal_end_time': '2024-07-16', 'record_time': '2024-05-22 18:46:30'}
# sql query :
#     INSERT INTO `schedule_1`
#     (user_id,user_goal,goal_complexity,goal_start_time,goal_end_time,record_time)
#     VALUES
#     (%s,%s,%s,%s,%s,%s)
#
# sql insert data :  {'user_id': 'MxODNuYnKs', 'user_goal': 'fhHPJ1KL61', 'goal_complexity': 5, 'goal_start_time': '2024-06-29', 'goal_end_time': '2024-07-03', 'record_time': '2024-06-02 18:46:30'}
# sql query :
#     INSERT INTO `schedule_1`
#     (user_id,user_goal,goal_complexity,goal_start_time,goal_end_time,record_time)
#     VALUES
#     (%s,%s,%s,%s,%s,%s)
#
# sql insert data :  {'user_id': 'aioQCDcjmI', 'user_goal': 'p8J72CZNaq', 'goal_complexity': 3, 'goal_start_time': '2024-06-25', 'goal_end_time': '2024-06-27', 'record_time': '2024-06-16 18:46:30'}
# sql query :
#     INSERT INTO `schedule_1`
#     (user_id,user_goal,goal_complexity,goal_start_time,goal_end_time,record_time)
#     VALUES
#     (%s,%s,%s,%s,%s,%s)
#
# sql insert data :  {'user_id': 'vX1RDnmedL', 'user_goal': 'xTkU9jbhkv', 'goal_complexity': 4, 'goal_start_time': '2024-06-27', 'goal_end_time': '2024-07-11', 'record_time': '2024-05-26 18:46:30'}
# sql query :
#     INSERT INTO `schedule_1`
#     (user_id,user_goal,goal_complexity,goal_start_time,goal_end_time,record_time)
#     VALUES
#     (%s,%s,%s,%s,%s,%s)
#
# sql insert data :  {'user_id': 'fuDoEnxHs9', 'user_goal': 'CzTVJgb7b2', 'goal_complexity': 5, 'goal_start_time': '2024-06-19', 'goal_end_time': '2024-07-13', 'record_time': '2024-05-20 18:46:30'}
# sql query :
#     INSERT INTO `schedule_1`
#     (user_id,user_goal,goal_complexity,goal_start_time,goal_end_time,record_time)
#     VALUES
#     (%s,%s,%s,%s,%s,%s)
#
# sql insert data :  {'user_id': 'aioQCDcjmI', 'user_goal': 'HUmUo9Tynh', 'goal_complexity': 1, 'goal_start_time': '2024-07-12', 'goal_end_time': '2024-07-20', 'record_time': '2024-06-04 18:46:30'}
# sql query :
#     INSERT INTO `schedule_1`
#     (user_id,user_goal,goal_complexity,goal_start_time,goal_end_time,record_time)
#     VALUES
#     (%s,%s,%s,%s,%s,%s)
#
# sql insert data :  {'user_id': 'xzdddiDlJA', 'user_goal': 'buSu91kgtN', 'goal_complexity': 4, 'goal_start_time': '2024-06-21', 'goal_end_time': '2024-06-29', 'record_time': '2024-06-02 18:46:30'}
# sql query :
#     INSERT INTO `schedule_1`
#     (user_id,user_goal,goal_complexity,goal_start_time,goal_end_time,record_time)
#     VALUES
#     (%s,%s,%s,%s,%s,%s)
#
# sql insert data :  {'user_id': 'ngaTkjk7B9', 'user_goal': 'WYyQbTGZpB', 'goal_complexity': 3, 'goal_start_time': '2024-07-18', 'goal_end_time': '2024-08-11', 'record_time': '2024-05-28 18:46:30'}
# sql query :
#     INSERT INTO `schedule_1`
#     (user_id,user_goal,goal_complexity,goal_start_time,goal_end_time,record_time)
#     VALUES
#     (%s,%s,%s,%s,%s,%s)
#
# sql insert data :  {'user_id': 'WZWZHNasYh', 'user_goal': 'ufQJXAkz47', 'goal_complexity': 2, 'goal_start_time': '2024-07-07', 'goal_end_time': '2024-08-06', 'record_time': '2024-06-14 18:46:30'}

# %%
# 저장 프로시저 호출
db.sql_query("CALL update_base_weight_no()")
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# Cell In[6], line 2
#       1 # 저장 프로시저 호출
# ----> 2 db.sql_query("CALL update_base_weight_no()")
#
# File c:\Users\USER\Documents\GitHub\todo_list\refer\module\database.py:35, in MyDB.sql_query(self, _sql, *_values)
#      33 cursor = mydb.cursor(pymysql.cursors.DictCursor)
#      34 # _sql, _values를 이용하여 cursor에게 질의를 보낸다.
# ---> 35 cursor.execute(_sql, _values)
#      36 # _sql이 select문인지 확인
#      37 if _sql.strip().lower().startswith('select'):
#
# File c:\Users\USER\AppData\Local\Programs\Python\Python312\Lib\site-packages\pymysql\cursors.py:153, in Cursor.execute(self, query, args)
#     149     pass
#     151 query = self.mogrify(query, args)
# --> 153 result = self._query(query)
#     154 self._executed = query
#     155 return result
#
# File c:\Users\USER\AppData\Local\Programs\Python\Python312\Lib\site-packages\pymysql\cursors.py:322, in Cursor._query(self, q)
#     320 conn = self._get_db()
#     321 self._clear_result()
# --> 322 conn.query(q)
#     323 self._do_get_result()
#     324 return self.rowcount
#
# File c:\Users\USER\AppData\Local\Programs\Python\Python312\Lib\site-packages\pymysql\connections.py:558, in Connection.query(self, sql, unbuffered)
#     556     sql = sql.encode(self.encoding, "surrogateescape")
#     557 self._execute_command(COMMAND.COM_QUERY, sql)
# --> 558 self._affected_rows = self._read_query_result(unbuffered=unbuffered)
#     559 return self._affected_rows
#
# File c:\Users\USER\AppData\Local\Programs\Python\Python312\Lib\site-packages\pymysql\connections.py:822, in Connection._read_query_result(self, unbuffered)
#     820 else:
#     821     result = MySQLResult(self)
# --> 822     result.read()
#     823 self._result = result
#     824 if result.server_status is not None:
#
# File c:\Users\USER\AppData\Local\Programs\Python\Python312\Lib\site-packages\pymysql\connections.py:1200, in MySQLResult.read(self)
#    1198 def read(self):
#    1199     try:
# -> 1200         first_packet = self.connection._read_packet()
#    1202         if first_packet.is_ok_packet():
#    1203             self._read_ok_packet(first_packet)
#
# File c:\Users\USER\AppData\Local\Programs\Python\Python312\Lib\site-packages\pymysql\connections.py:772, in Connection._read_packet(self, packet_type)
#     770     if self._result is not None and self._result.unbuffered_active is True:
#     771         self._result.unbuffered_active = False
# --> 772     packet.raise_for_error()
#     773 return packet
#
# File c:\Users\USER\AppData\Local\Programs\Python\Python312\Lib\site-packages\pymysql\protocol.py:221, in MysqlPacket.raise_for_error(self)
#     219 if DEBUG:
#     220     print("errno =", errno)
# --> 221 err.raise_mysql_exception(self._data)
#
# File c:\Users\USER\AppData\Local\Programs\Python\Python312\Lib\site-packages\pymysql\err.py:143, in raise_mysql_exception(data)
#     141 if errorclass is None:
#     142     errorclass = InternalError if errno < 1000 else OperationalError
# --> 143 raise errorclass(errno, errval)
#
# OperationalError: (1054, "Unknown column 'user_id' in 'where clause'")

# %% [markdown]
# ### user_weight
#
# - work
# - edu
# - free_time
# - health
# - chores
# - category_else

# %%
import random

# 랜덤한 0부터 1 사이의 double 값을 생성하는 함수
def generate_random_double():
    return round(random.uniform(0, 1), 2)  # 소수점 2자리까지

# 랜덤한 데이터를 생성하는 함수
def generate_random_user_weight_data(num_records=100):
    data = []
    for _ in range(num_records):
        record = {
            'work': generate_random_double(),
            'edu': generate_random_double(),
            'free_time': generate_random_double(),
            'health': generate_random_double(),
            'chores': generate_random_double(),
            'category_else': generate_random_double()
        }
        data.append(record)
    return data

# 데이터 생성
num_records = 100  # 생성할 레코드 수
user_weight_data = generate_random_user_weight_data(num_records)

# 데이터 확인
print(user_weight_data[:5])  # 데이터의 상위 5개 항목을 출력하여 확인

save_data(user_weight_data, 'user_weight')
# Out:
# [{'work': 0.74, 'edu': 0.38, 'free_time': 0.33, 'health': 0.54, 'chores': 0.13, 'category_else': 0.82}, {'work': 0.32, 'edu': 0.42, 'free_time': 0.5, 'health': 0.35, 'chores': 0.85, 'category_else': 0.5}, {'work': 0.58, 'edu': 0.32, 'free_time': 0.28, 'health': 0.3, 'chores': 0.07, 'category_else': 0.6}, {'work': 0.77, 'edu': 0.13, 'free_time': 0.88, 'health': 0.02, 'chores': 0.68, 'category_else': 0.23}, {'work': 0.27, 'edu': 0.67, 'free_time': 0.27, 'health': 0.95, 'chores': 0.12, 'category_else': 0.21}]
# save_list_data record :  <class 'dict'>
# sql query :
#     INSERT INTO `user_weight`
#     (work,edu,free_time,health,chores,category_else)
#     VALUES
#     (%s,%s,%s,%s,%s,%s)
#
# sql insert data :  {'work': 0.74, 'edu': 0.38, 'free_time': 0.33, 'health': 0.54, 'chores': 0.13, 'category_else': 0.82}
# save_list_data record :  <class 'dict'>
# sql query :
#     INSERT INTO `user_weight`
#     (work,edu,free_time,health,chores,category_else)
#     VALUES
#     (%s,%s,%s,%s,%s,%s)
#
# sql insert data :  {'work': 0.32, 'edu': 0.42, 'free_time': 0.5, 'health': 0.35, 'chores': 0.85, 'category_else': 0.5}
# save_list_data record :  <class 'dict'>
# sql query :
#     INSERT INTO `user_weight`
#     (work,edu,free_time,health,chores,category_else)
#     VALUES
#     (%s,%s,%s,%s,%s,%s)
#
# sql insert data :  {'work': 0.58, 'edu': 0.32, 'free_time': 0.28, 'health': 0.3, 'chores': 0.07, 'category_else': 0.6}
# save_list_data record :  <class 'dict'>
# sql query :
#     INSERT INTO `user_weight`
#     (work,edu,free_time,health,chores,category_else)
#     VALUES
#     (%s,%s,%s,%s,%s,%s)
#
# sql insert data :  {'work': 0.77, 'edu': 0.13, 'free_time': 0.88, 'health': 0.02, 'chores': 0.68, 'category_else': 0.23}
# save_list_data record :  <class 'dict'>
# sql query :
#     INSERT INTO `user_weight`
#     (work,edu,free_time,health,chores,category_else)
#     VALUES
#     (%s,%s,%s,%s,%s,%s)
#
# sql insert data :  {'work': 0.27, 'edu': 0.67, 'free_time': 0.27, 'health': 0.95, 'chores': 0.12, 'category_else': 0.21}
# save_list_data record :  <class 'dict'>
# sql query :
#     INSERT INTO `user_weight`
#     (work,edu,free_time,health,chores,category_else)
#     VALUES
#     (%s,%s,%s,%s,%s,%s)
#
# sql insert data :  {'work': 0.77, 'edu': 0.38, 'free_time': 0.92, 'health': 0.11, 'chores': 0.37, 'category_else': 0.01}
# save_list_data record :  <class 'dict'>
# sql query :
#     INSERT INTO `user_weight`
#     (work,edu,free_time,health,chores,category_else)
#     VALUES
#     (%s,%s,%s,%s,%s,%s)
#
# sql insert data :  {'work': 0.73, 'edu': 0.51, 'free_time': 0.06, 'health': 0.29, 'chores': 0.11, 'category_else': 0.52}
# save_list_data record :  <class 'dict'>
# sql query :
#     INSERT INTO `user_weight`
#     (work,edu,free_time,health,chores,category_else)
#     VALUES
#     (%s,%s,%s,%s,%s,%s)
#
# sql insert data :  {'work': 0

# save_list_data record :  <class 'dict'>
# sql query :
#     INSERT INTO `user_weight`
#     (work,edu,free_time,health,chores,category_else)
#     VALUES
#     (%s,%s,%s,%s,%s,%s)
#
# sql insert data :  {'work': 0.55, 'edu': 0.74, 'free_time': 0.9, 'health': 0.88, 'chores': 0.26, 'category_else': 0.5}
# save_list_data record :  <class 'dict'>
# sql query :
#     INSERT INTO `user_weight`
#     (work,edu,free_time,health,chores,category_else)
#     VALUES
#     (%s,%s,%s,%s,%s,%s)
#
# sql insert data :  {'work': 0.71, 'edu': 0.74, 'free_time': 0.48, 'health': 0.31, 'chores': 0.53, 'category_else': 0.19}
# save_list_data record :  <class 'dict'>
# sql query :
#     INSERT INTO `user_weight`
#     (work,edu,free_time,health,chores,category_else)
#     VALUES
#     (%s,%s,%s,%s,%s,%s)
#
# sql insert data :  {'work': 0.04, 'edu': 0.75, 'free_time': 0.3, 'health': 0.29, 'chores': 0.46, 'category_else': 0.84}
# save_list_data record :  <class 'dict'>
# sql query :
#     INSERT INTO `user_weight`
#     (work,edu,free_time,health,chores,category_else)
#     VALUES
#     (%s,%s,%s,%s,%s,%s)
#
# sql insert data :  {'work': 0.73, 'edu': 0.5, 'free_time': 0.25, 'health': 0.52, 'chores': 0.74, 'category_else': 0.34}
# save_list_data record :  <class 'dict'>
# sql query :
#     INSERT INTO `user_weight`
#     (work,edu,free_time,health,chores,category_else)
#     VALUES
#     (%s,%s,%s,%s,%s,%s)
#
# sql insert data :  {'work': 0.84, 'edu': 0.64, 'free_time': 0.53, 'health': 0.1, 'chores': 0.51, 'category_else': 0.63}
# save_list_data record :  <class 'dict'>
# sql query :
#     INSERT INTO `user_weight`
#     (work,edu,free_time,health,chores,category_else)
#     VALUES
#     (%s,%s,%s,%s,%s,%s)
#
# sql insert data :  {'work': 0.01, 'edu': 0.48, 'free_time': 0.6, 'health': 0.22, 'chores': 0.46, 'category_else': 0.55}
# save_list_data record :  <class 'dict'>
# sql query :
#     INSERT INTO `user_weight`
#     (work,edu,free_time,health,chores,category_else)
#     VALUES
#     (%s,%s,%s,%s,%s,%s)
#
# sql insert data :  {'work': 0.54, 'edu': 0.04, 'free_time': 0.94, 'health': 0.49, 'chores': 0.07, 'category_else': 0.99}
# save_list_data record :  <class 'dict'>
# sql query :
#     INSERT INTO `user_weight`
#     (work,edu,free_time,health,chores,category_else)
#     VALUES
#     (%s,%s,%s,%s,%s,%s)
#
# sql insert data :  {'work': 0.39, 'edu': 0.35, 'free_time': 0.06, 'health': 0.07, 'chores': 0.53, 'category_else': 0.75}

# %%
import pandas as pd
import random

# 랜덤한 0부터 1 사이의 double 값을 생성하는 함수
def generate_random_double():
    return round(random.uniform(0, 1), 2)  # 소수점 2자리까지

# 랜덤한 데이터를 생성하는 함수
def generate_random_user_weight_data(num_records=100):
    data = {
        'user_weight_no': [],
        'work': [],
        'edu': [],
        'free_time': [],
        'health': [],
        'chores': [],
        'category_else': []
    }
    
    for i in range(1, num_records + 1):
        data['user_weight_no'].append(i)
        data['work'].append(generate_random_double())
        data['edu'].append(generate_random_double())
        data['free_time'].append(generate_random_double())
        data['health'].append(generate_random_double())
        data['chores'].append(generate_random_double())
        data['category_else'].append(generate_random_double())
    
    return pd.DataFrame(data)

# 데이터 생성
num_records = 100  # 생성할 레코드 수
user_weight_data = generate_random_user_weight_data(num_records)



# 데이터를 CSV 파일로 저장
csv_file_path = './user_weight.csv'
user_weight_data.to_csv(csv_file_path, index=False)

print(f"Data saved to {csv_file_path}")

# %%
import pandas as pd
from refer.module.database import MyDB

# MyDB 클래스 생성
db = MyDB()

# SQL 쿼리 실행
query = """
SELECT 
    s.sc1,
    s.user_id,
    s.user_goal,
    s.record_time,
    s.goal_complexity,
    s.goal_start_time,
    s.goal_end_time,
    s.base_weight_no,
    b.gender,
    b.job,
    b.mbti,
    b.age,
    b.work,
    b.edu,
    b.free_time,
    b.health,
    b.chores,
    b.category_else
FROM 
    schedule_1 s
JOIN 
    base_weight b ON s.base_weight_no = b.no;
"""

# 쿼리 결과 가져오기
result = db.sql_query(query)

# 결과를 DataFrame으로 변환
df_result = pd.DataFrame(result)

# 결과 확인
df_result.head()
# Out:
# sql_query :
# SELECT
#     s.sc1,
#     s.user_id,
#     s.user_goal,
#     s.record_time,
#     s.goal_complexity,
#     s.goal_start_time,
#     s.goal_end_time,
#     s.base_weight_no,
#     b.gender,
#     b.job,
#     b.mbti,
#     b.age,
#     b.work,
#     b.edu,
#     b.free_time,
#     b.health,
#     b.chores,
#     b.category_else
# FROM
#     schedule_1 s
# JOIN
#     base_weight b ON s.base_weight_no = b.no;
# Empty DataFrame
# Columns: []
# Index: []

# %%
df_result
# Out:
# Empty DataFrame
# Columns: []
# Index: []
