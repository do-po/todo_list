# %%
import pandas as pd

# %%
survey = pd.read_csv('./survey.csv')

# %%
survey
# Out:
#     age             job  mbti  gender  work   edu  free_time  health  chores
# 0    27      job_seeker  INTJ       0  0.25  0.75       1.00    1.00    0.50
# 1    28      job_seeker  INTJ       0  1.00  0.50       0.25    0.00    0.75
# 2    28          senior  ESFP       1  0.75  0.50       1.00    0.25    0.00
# 3    23          senior  INTP       0  0.50  0.50       0.50    0.50    0.50
# 4    27      job_seeker  ISTP       0  0.75  0.75       0.50    1.00    0.50
# 5    29      job_seeker  ESTP       0  1.00  0.50       0.75    0.50    0.00
# 6    29          senior  INTP       0  0.50  1.00       1.00    1.00    0.50
# 7    27      job_seeker  INTP       0  0.75  0.75       0.50    0.50    0.50
# 8    22          senior  ISTP       1  1.00  0.75       0.75    0.75    0.50
# 9    27      job_seeker  ENTP       0  1.00  0.75       1.00    1.00    0.50
# 10   28      job_seeker  ESTP       1  1.00  0.50       0.75    1.00    0.50
# ...
